# %%
import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import datasets.python_format as dataset

# %%
# TODO: try one-hot instead of embedding
# TODO: if too long - filter wont see all context
# TODO: if too small - downsampling might sample to 0 size

# %%
max_len = 100

def batch_gen(batch_size):
  gen = dataset.gen(1, 7)
  
  while True:
    x, y = [], []
    x_len, y_len = [], []
    for i in range(batch_size):
      batch = next(gen)
      x.append(batch[0])
      y.append(batch[1])
      x_len.append(len(batch[0]))
      y_len.append(len(batch[1]))

    x_max_len = max_len
    y_max_len = max_len

    for i in range(batch_size):
      x[i] = x[i] + [dataset.pad] * (x_max_len - len(x[i]))
      y[i] = y[i] + [dataset.pad] * (y_max_len - len(y[i]))

    x = torch.LongTensor(x)
    y = torch.LongTensor(y)
    
    yield x, y

# %%
class ConvBNRelu(nn.Module):
  def __init__(self, input, output, kernel):
    super().__init__()
    
    self.conv = nn.Conv2d(input, output, kernel)
    self.bn = nn.BatchNorm2d(output)
    
  def forward(self, x):
    x = self.conv(x)
    x = self.bn(x)
    x = F.relu(x)
    
    return x
  
class ConvTransposeBNRelu(nn.Module):
  def __init__(self, input, output, kernel):
    super().__init__()
    
    self.conv_t = nn.ConvTranspose2d(input, output, kernel)
    self.bn = nn.BatchNorm2d(output)
    
  def forward(self, x):
    x = self.conv_t(x)
    x = self.bn(x)
    x = F.relu(x)
    
    return x
  
class ResidualBlock(nn.Module):
  def __init__(self, size, kernel):
    self.conv1 = nn.Conv2d(size, size, kernel)
    self.bn1 = nn.BatchNorm2d(size)
    self.conv2 = nn.Conv2d(size, size, kernel)
    self.bn2 = nn.BatchNorm2d(size)
    
  def forward(self, x):
    saved = x
    x = self.conv1(x)
    x = self.bn1(x)
    x = F.relu(x)
    
    x = self.conv2(x)
    x = self.bn2(x)
    x = x + saved
    x = F.relu(x)
    
    return x
    

class Net(nn.Module):
  def __init__(self):
    super(Net, self).__init__()
    
    self.embedding = nn.Embedding(dataset.vocab_size, dataset.vocab_size)
    
    self.conv_bn_relu1 = ConvBNRelu(1, 16, 3)
    self.conv_bn_relu2 = ConvBNRelu(16, 16, 3)
    self.conv_bn_relu3 = ConvBNRelu(16, 16, 3)
    self.conv_bn_relu4 = ConvBNRelu(16, 16, 3)
    self.conv_bn_relu5 = ConvBNRelu(16, 16, 3)
    self.conv_bn_relu6 = ConvBNRelu(16, 16, 3)
    
    self.conv_t_bn_relu7 = ConvTransposeBNRelu(16, 16, 3)
    self.conv_t_bn_relu8 = ConvTransposeBNRelu(16, 16, 3)
    self.conv_t_bn_relu9 = ConvTransposeBNRelu(16, 16, 3)
    self.conv_t_bn_relu10 = ConvTransposeBNRelu(16, 16, 3)
    self.conv_t_bn_relu11 = ConvTransposeBNRelu(16, 16, 3)
    self.conv_t_bn_relu12 = ConvTransposeBNRelu(16, 1, 3)
    
  def forward(self, x):
    x = self.embedding(x)
    x = x.unsqueeze(1)
    
    x = self.conv_bn_relu1(x)
    x = self.conv_bn_relu2(x)
    x, pi2 = F.max_pool2d(x, 2, 2, return_indices=True)
    
    x = self.conv_bn_relu3(x)
    x = self.conv_bn_relu4(x)
    x, pi4 = F.max_pool2d(x, 2, 2, return_indices=True)
    
    x = self.conv_bn_relu5(x)
    x = self.conv_bn_relu6(x)
#     x, pi6 = F.max_pool2d(x, 2, 2, return_indices=True)
    
#     x = F.max_unpool2d(x, pi6, 2, 2)
    x = self.conv_t_bn_relu7(x)
    x = self.conv_t_bn_relu8(x)
    
    x = F.max_unpool2d(x, pi4, 2, 2)
    x = self.conv_t_bn_relu8(x)
    x = self.conv_t_bn_relu10(x)
    
    x = F.max_unpool2d(x, pi2, 2, 2)
    x = self.conv_t_bn_relu11(x)
    x = self.conv_t_bn_relu12(x)
    
    x = x.squeeze()
    x = F.log_softmax(x, dim=-1)
    return x
  

model = Net()
print(model)
# Out:
# Net(
#   (embedding): Embedding(72, 72)
#   (conv_bn_relu1): ConvBNRelu(
#     (conv): Conv2d (1, 16, kernel_size=(3, 3), stride=(1, 1))
#     (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True)
#   )
#   (conv_bn_relu2): ConvBNRelu(
#     (conv): Conv2d (16, 16, kernel_size=(3, 3), stride=(1, 1))
#     (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True)
#   )
#   (conv_bn_relu3): ConvBNRelu(
#     (conv): Conv2d (16, 16, kernel_size=(3, 3), stride=(1, 1))
#     (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True)
#   )
#   (conv_bn_relu4): ConvBNRelu(
#     (conv): Conv2d (16, 16, kernel_size=(3, 3), stride=(1, 1))
#     (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True)
#   )
#   (conv_bn_relu5): ConvBNRelu(
#     (conv): Conv2d (16, 16, kernel_size=(3, 3), stride=(1, 1))
#     (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True)
#   )
#   (conv_bn_relu6): ConvBNRelu(
#     (conv): Conv2d (16, 16, kernel_size=(3, 3), stride=(1, 1))
#     (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True)
#   )
#   (conv_t_bn_relu7): ConvTransposeBNRelu(
#     (conv_t): ConvTranspose2d (16, 16, kernel_size=(3, 3), stride=(1, 1))
#     (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True)
#   )
#   (conv_t_bn_relu8): ConvTransposeBNRelu(
#     (conv_t): ConvTranspose2d (16, 16, kernel_size=(3, 3), stride=(1, 1))
#     (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True)
#   )
#   (conv_t_bn_relu9): ConvTransposeBNRelu(
#     (conv_t): ConvTranspose2d (16, 16, kernel_size=(3, 3), stride=(1, 1))
#     (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True)
#   )
#   (conv_t_bn_relu10): ConvTransposeBNRelu(
#     (conv_t): ConvTranspose2d (16, 16, kernel_size=(3, 3), stride=(1, 1))
#     (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True)
#   )
#   (conv_t_bn_relu11): ConvTransposeBNRelu(
#     (conv_t): ConvTranspose2d (16, 16, kernel_size=(3, 3), stride=(1, 1))
#     (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True)
#   )
#   (conv_t_bn_relu12): ConvTransposeBNRelu(
#     (conv_t): ConvTranspose2d (16, 1, kernel_size=(3, 3), stride=(1, 1))
#     (bn): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True)
#   )
# )

# %%
learning_rate = 0.001
batch_size = 32
steps = 2000
log_interval = 10

optimizer = optim.Adam(model.parameters(), lr=learning_rate)
gen = batch_gen(batch_size)
test_gen = batch_gen(batch_size * 10)

for i in range(steps + 1):
  model.train()

  x, y = next(gen)
  x, y = Variable(x), Variable(y)
  optimizer.zero_grad()
  y_hat = model(x)
  y_hat = y_hat.view(-1, y_hat.size(-1))
  y = y.view(-1)
  loss = F.nll_loss(y_hat, y)
  loss.backward()
  optimizer.step()

  if i % log_interval == 0:
    model.eval()

    x, y = next(test_gen)
    x, y = Variable(x, volatile=True), Variable(y)
    y_hat = model(x)
    y_hat = y_hat.view(-1, y_hat.size(-1))
    y = y.view(-1)
    test_loss = F.nll_loss(y_hat, y) # sum up batch loss
    pred = y_hat.max(1, keepdim=True)[1].squeeze() # get the index of the max log-probability
    accuracy = (pred == y).float().mean() * 100
    
    print('step: {}, loss: {:.4f}, accuracy: {:.2f}%'.format(
        i, test_loss.data[0], accuracy.data[0]))
    
    print('\tsample:    {}\n\ttrue:      {}\n\tpredicted: {}'.format(
      dataset.decode(x[0].tolist()),
      dataset.decode(y[:max_len].tolist()),
      dataset.decode(pred[:max_len].tolist())))
# Out:
# step: 0, loss: 4.2741, accuracy: 74.93%
# 	sample:    Quae Molestiae<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      Quae Molestiae<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted: Aw<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>}<p>
# step: 10, loss: 4.2410, accuracy: 75.17%
# 	sample:    maxime {}% {} {} {} {}-th<f>471<n>nemo<n>quam<n>21<n>360<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      maxime 471% nemo quam 21 360-th<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted: <p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# step: 20, loss: 3.9933, accuracy: 76.26%
# 	sample:    192 {} {} {} voluptatum Quo<f>amet<n>605<n>NATUS<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      192 amet 605 NATUS voluptatum Quo<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted: <p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# step: 30, loss: 3.2249, accuracy: 76.30%
# 	sample:    NISI: 785<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      NISI: 785<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted: <p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# step: 40, loss: 2.1235, accuracy: 75.73%
# 	sample:    {} 755 {}-th {}<f>maiores<n>30<n>laboriosam<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      maiores 755 30-th laboriosam<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted: <p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# step: 50, loss: 1.6457, accuracy: 74.35%
# 	sample:    {} {}-th {}: {} {}: {}<f>Possimus<n>33<n>Dignissimos<n>592<n>HARUM<n>33<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      Possimus 33-th Dignissimos: 592 HARUM: 33<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted: <p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# step: 60, loss: 1.4169, accuracy: 76.65%
# 	sample:    {} 660%<f>Nihil<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      Nihil 660%<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted: <p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# step: 70, loss: 1.4267, accuracy: 75.26%
# 	sample:    {}<f>Iste<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      Iste<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted: <p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# step: 80, loss: 1.3420, accuracy: 76.39%
# 	sample:    {} {}<f>262<n>549<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      262 549<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted: <p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# step: 90, loss: 1.3411, accuracy: 75.69%
# 	sample:    AT {} 51-th 373-th {}-th {}-th<f>Dignissimos<n>484<n>93<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      AT Dignissimos 51-th 373-th 484-th 93-th<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted: <p><p><p><p><p> <p><p> <p>  <p><p><p><p><p><p> <p><p><p> <p> <p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# step: 100, loss: 1.3089, accuracy: 75.85%
# 	sample:    {} {} {}: {}<f>Dolores<n>maxime<n>Temporibus<n>982<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      Dolores maxime Temporibus: 982<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted: <p><p><p>    <p><p><p> <p><p><p><p><p><p><p><p><p><p><p> <p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# step: 110, loss: 1.3479, accuracy: 75.28%
# 	sample:    {} cum deserunt voluptatibus {}<f>601<n>dolor<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      601 cum deserunt voluptatibus dolor<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted: <p><p><p><p><p><p><p> <p> <p>   <p>  <p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# step: 120, loss: 1.2531, accuracy: 77.11%
# 	sample:    eum Laboriosam {} {}-th {}<f>276<n>15<n>579<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      eum Laboriosam 276 15-th 579<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted: <p><p><p><p><p><p><p><p><p><p>               <p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# step: 130, loss: 1.2310, accuracy: 77.72%
# 	sample:    {}% {}% {} {} 850 {}<f>631<n>593<n>repellendus<n>Totam<n>occaecati<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      631% 593% repellendus Totam 850 occaecati<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted: <p><p><p>           <p><p>    <p><p><p><p>  <p><p>   <p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# step: 140, loss: 1.2091, accuracy: 77.72%
# 	sample:    {} 313-th DUCIMUS Repudiandae {}% 956%<f>modi<n>810<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      modi 313-th DUCIMUS Repudiandae 810% 956%<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted: <p><p><p><p>    l<p><p><p>   <p>   M <p>   <p><p><p><p><p><p>t<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# step: 150, loss: 1.1833, accuracy: 77.85%
# 	sample:    {} {} {} ullam {}-th<f>Quod<n>Soluta<n>minus<n>814<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      Quod Soluta minus ullam 814-th<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted:          <p><p><p><p>             <p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# step: 160, loss: 1.2390, accuracy: 76.62%
# 	sample:    {} {}-th 458-th<f>quisquam<n>957<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      quisquam 957-th 458-th<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted: <p><p><p>        <p> <p>  <p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# step: 170, loss: 1.1702, accuracy: 78.08%
# 	sample:    {}: {} {}-th At: 879<f>et<n>991<n>987<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      et: 991 987-th At: 879<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted: <p><p><p><p>     h       <p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# step: 180, loss: 1.2330, accuracy: 76.48%
# 	sample:    {}<f>Dolor<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      Dolor<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted: <p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# step: 190, loss: 1.1289, accuracy: 78.74%
# 	sample:    {}<f>LABORUM<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      LABORUM<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted: <p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# step: 200, loss: 1.1589, accuracy: 78.09%
# 	sample:    {} QUIS: 905 {}: {} 602%<f>facere<n>Ipsam<n>365<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      facere QUIS: 905 Ipsam: 365 602%<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted: <p>  <p>   Bhh       Na h   <p>   <p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# step: 210, loss: 1.2347, accuracy: 76.32%
# 	sample:    {} {}: {} EXPLICABO {} 770-th {}<f>Officia<n>neque<n>312<n>QUO<n>QUAERAT<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      Officia neque: 312 EXPLICABO QUO 770-th QUAERAT<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted: <p>      feeee         h   ae6u  onDeT <p>     <p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# step: 220, loss: 1.1977, accuracy: 77.07%
# 	sample:    {} 812-th {} aperiam<f>393<n>Minus<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      393 812-th Minus aperiam<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted:               udC<p><p>  <p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# step: 230, loss: 1.1963, accuracy: 77.21%
# 	sample:    {} {}<f>Reiciendis<n>270<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      Reiciendis 270<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted: <p><p><p>    z   <p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# step: 240, loss: 1.1989, accuracy: 76.62%
# 	sample:    {} 468-th commodi {}: {} 47-th<f>sint<n>Veniam<n>727<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      sint 468-th commodi Veniam: 727 47-th<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted: e      <p>e    <p><p> tttt<p><p> te6eaetat<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# step: 250, loss: 1.1562, accuracy: 77.52%
# 	sample:    {} {}-th {} {} {}%<f>nemo<n>587<n>ID<n>829<n>502<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      nemo 587-th ID 829 502%<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted:   <p>       o  h  ee   <p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# step: 260, loss: 1.1325, accuracy: 77.75%
# 	sample:    {} {}<f>Sequi<n>esse<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      Sequi esse<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted:   <p>   <p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# step: 270, loss: 1.1533, accuracy: 77.37%
# 	sample:    Veritatis {}<f>Praesentium<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      Veritatis Praesentium<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted: <p><p><p><p>       Vuuuus t<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# step: 280, loss: 1.1315, accuracy: 77.99%
# 	sample:    {} {}<f>411<n>quis<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      411 quis<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted:  <p><p><p> <p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# step: 290, loss: 1.1506, accuracy: 77.81%
# 	sample:    {} {} iusto {}-th {} {}<f>officia<n>987<n>171<n>Fugit<n>255<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      officia 987 iusto 171-th Fugit 255<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted:               ue   V   e  ue <p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# step: 300, loss: 1.0885, accuracy: 78.93%
# 	sample:    sunt 35% {}<f>accusantium<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      sunt 35% accusantium<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted: af<p> <p>     <p><p>u%hhAA<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# step: 310, loss: 1.0869, accuracy: 78.62%
# 	sample:    {} {}: {} {} {}<f>Saepe<n>Voluptas<n>998<n>Culpa<n>Labore<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      Saepe Voluptas: 998 Culpa Labore<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted:            o       tut  9<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# step: 320, loss: 1.2165, accuracy: 75.62%
# 	sample:    {} fugit {} magnam {} {}%<f>336<n>Tenetur<n>283<n>735<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      336 fugit Tenetur magnam 283 735%<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted:             K: e at    2    e <p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# step: 330, loss: 1.1092, accuracy: 78.11%
# 	sample:    {} {}% Dolorem TEMPORE<f>OMNIS<n>293<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      OMNIS 293% Dolorem TEMPORE<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted: ee<p>       ettt etttttt  <p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# step: 340, loss: 1.1187, accuracy: 77.66%
# 	sample:    {}% {}-th {} {}<f>850<n>60<n>257<n>odit<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      850% 60-th 257 odit<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted: ea<p>%           <p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# step: 350, loss: 1.0982, accuracy: 77.98%
# 	sample:    {} 858 {}-th<f>48<n>610<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      48 858 610-th<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted: {       <p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# step: 360, loss: 1.0795, accuracy: 78.24%
# 	sample:    {}-th {} {} {}<f>54<n>259<n>NUMQUAM<n>nemo<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      54-th 259 NUMQUAM nemo<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted: eeb-   h   eeeei :<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# step: 370, loss: 1.1094, accuracy: 77.37%
# 	sample:    repellat: 259 occaecati: 342<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	true:      repellat: 259 occaecati: 342<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# 	predicted:       drr     ss  e<p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-41a175ac1708> in <module>()
#      14   x, y = Variable(x), Variable(y)
#      15   optimizer.zero_grad()
# ---> 16   y_hat = model(x)
#      17   y_hat = y_hat.view(-1, y_hat.size(-1))
#      18   y = y.view(-1)
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# <ipython-input-4-e9a59143e5c7> in forward(self, x)
#      89
#      90     x = F.max_unpool2d(x, pi4, 2, 2)
# ---> 91     x = self.conv_t_bn_relu8(x)
#      92     x = self.conv_t_bn_relu10(x)
#      93
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# <ipython-input-4-e9a59143e5c7> in forward(self, x)
#      21
#      22   def forward(self, x):
# ---> 23     x = self.conv_t(x)
#      24     x = self.bn(x)
#      25     x = F.relu(x)
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/conv.py in forward(self, input, output_size)
#     604         return F.conv_transpose2d(
#     605             input, self.weight, self.bias, self.stride, self.padding,
# --> 606             output_padding, self.groups, self.dilation)
#     607
#     608
#
# /usr/local/lib/python3.6/site-packages/torch/nn/functional.py in conv_transpose2d(input, weight, bias, stride, padding, output_padding, groups, dilation)
#     190                 _pair(output_padding), groups, torch.backends.cudnn.benchmark,
#     191                 torch.backends.cudnn.deterministic, torch.backends.cudnn.enabled)
# --> 192     return f(input, weight, bias)
#     193
#     194
#
# KeyboardInterrupt:
